                     "9760:JP", "9761:JP", "9762:JP", "9763:JP", "9764:JP",
                     "9765:JP", "9766:JP", "9767:JP", "9768:JP", "9769:JP",
                     "9770:JP", "9771:JP", "9772:JP", "9773:JP", "9774:JP",
                     "9775:JP", "9776:JP", "9777:JP", "9778:JP", "9779:JP",
                     "9780:JP", "9781:JP", "9782:JP", "9783:JP", "9784:JP",
                     "9785:JP", "9786:JP", "9787:JP", "9788:JP", "9789:JP",
                     "9790:JP", "9791:JP", "9792:JP", "9793:JP", "9794:JP",
                     "9795:JP", "9796:JP", "9797:JP", "9798:JP", "9799:JP",
                     "9801:JP", "9802:JP", "9803:JP", "6166:JP",
                     "9810:JP", "9811:JP", "9812:JP", "9813:JP", "9814:JP",
                     "9815:JP", "9816:JP", "9817:JP", "9818:JP", "9819:JP",
                     "9820:JP", "9821:JP", "9822:JP", "9823:JP", "9824:JP",
                     "9825:JP", "9826:JP", "9827:JP", "9828:JP", "9829:JP",
                     "9830:JP", "9831:JP", "9832:JP", "9833:JP", "9834:JP",
                     "9835:JP", "9836:JP", "9837:JP", "9838:JP", "9839:JP",
                     "9840:JP", "9841:JP", "9842:JP", "9843:JP", "9844:JP",
                     "9845:JP", "9846:JP", "9847:JP", "9848:JP", "9849:JP",
                     "9850:JP", "9851:JP", "9852:JP", "9853:JP", "9854:JP",
                     "9855:JP", "9856:JP", "9857:JP", "9858:JP", "9859:JP",
                     "9860:JP", "9861:JP", "9862:JP", "9863:JP", "9864:JP",
                     "9865:JP", "9866:JP", "9867:JP", "9868:JP", "9869:JP",
                     "9870:JP", "9871:JP", "9872:JP", "9873:JP", "9874:JP",
                     "9875:JP", "9876:JP", "9877:JP", "9878:JP", "9879:JP",
                     "9880:JP", "9881:JP", "9882:JP", "9883:JP", "9884:JP",
                     "9885:JP", "9886:JP", "9887:JP", "9888:JP", "9889:JP",
                     "9890:JP", "9891:JP", "9892:JP", "9893:JP", "9894:JP",
                     "9895:JP", "9896:JP", "9897:JP", "9898:JP", "9899:JP",
                     "9900:JP", "9901:JP", "9902:JP", "9903:JP", "9904:JP",
                     "9906:JP", "9907:JP", "9908:JP"]

ru_ticker_symbols = ["PHOR:RM", "SBER:LI", "SBER:RM", "URKA:RM"]

print(len(jp_ticker_symbols))
print(len(set(jp_ticker_symbols)))
# Out:
# 722
# 685

# %%
jp_symbols = [str(i) + ":JP" for i in range(1000,1005)]

# %%
def fetch_stock_data(symbol):
    sleep(2)
    resp = requests.get("https://www.bloomberg.com/quote/" + symbol)

    if resp.ok:
      html = BeautifulSoup(resp.text, "html.parser")
    else:
      print("error: {}".format(resp.status_code))
      return {"symbol": symbol, "name":"", "price": 0.0, "pe": 0.0, 
              "es": 0.0, "cap": 0.0}

    if html.find('h1', attrs={'class':'name'}) is None:
      print("X".format(resp.status_code))
      return {"symbol": symbol, "name":"", "price": 0.0, "pe": 0.0, 
              "es": 0.0, "cap": 0.0}
    
    sys.stdout.write('.')
    
    name = html.find('h1', attrs={'class':'name'}).text
    data_table = html.body.find('div', attrs={'class':'data-table_detailed'})
    entries = data_table.find_all('div')
    count_entries = len(entries)

    pe_ratio = 0.0
    e_per_share = 0.0
    market_cap = 0
    
    if len(entries) > 23:
        if "-" not in entries[23].text:
            pe_ratio = float(entries[23].text.replace(",",""))
        else:
            pe_ratio = 0.0

    if len(entries) > 26:
        if "-" not in entries[26].text:
            e_per_share = float(entries[26].text.replace(",",""))      
        else:
            e_per_share = 0.0
        
    price = float(entries[2].text.replace(",",""))
    
    if count_entries == 39:
        market_cap = entries[29].text
    else:
        market_cap = 0
    # ps_ratio = entries[35].text

    return {"symbol": symbol, "name":name, "price": price, "pe": pe_ratio, 
            "es": e_per_share, "cap": market_cap}


def fetch_stock_data_revised(symbol):
    sleep(2)
    resp = requests.get("https://www.bloomberg.com/quote/" + symbol)

    if resp.ok:
      html = BeautifulSoup(resp.text, "html.parser")
    else:
      print("error: {}".format(resp.status_code))
      return {"symbol": symbol, "name":"", "price": 0.0, "pe": 0.0, 
              "es": 0.0, "cap": 0.0}

    if html.find('h1', attrs={'class':'name'}) is None:
      print("X".format(resp.status_code))
      return {"symbol": symbol, "name":"", "price": 0.0, "pe": 0.0, 
              "es": 0.0, "cap": 0.0}
    
    sys.stdout.write('.')
    
    name = html.find('h1', attrs={'class':'name'}).text
    data_table = html.body.find('div', attrs={'class':'data-table_detailed'})
    entries = data_table.find_all('div')
    count_entries = len(entries)

    pe_ratio = 0.0
    e_per_share = 0.0
    market_cap = 0

    entry = {}

    for index in range(1, count_entries-1,2):
        tokens = entries[index].text.split("   ")
        
        if len(tokens) == 2:
            entry[tokens[0]] = tokens[1]
        else:
            entry[entries[index].text] = entries[index+1].text
            index += 1
            
    return entry

# %%
stock_data = []
for symbol in jp_ticker_symbols:
#   stock_data.append(fetch_stock_data(symbol))
    stock_data.append(fetch_stock_data_revised(symbol))
# Out:
# .......................................................................................................................................................................................................................................................................................................X
# ...X
# .X
# X
# X
# X
# X
# X
# X
# X
# X
# X
# ...........................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
df = pd.DataFrame(stock_data)
count = df.count()

df
# cutoff_threshold = int(count/3)
# df[df.pe != 0].sort_values("pe",ascending=True)
# Out:
#       1 Yr Return   52Wk Range   Current P/E Ratio (TTM)  \
# 0        71.95%            NaN                    7.77
# 1        51.50%            NaN                   23.98
# 2        70.52%            NaN                   11.22
# 3        46.14%            NaN                    9.12
# 4        32.94%            NaN                   13.27
# 5        64.01%            NaN                   11.55
# 6        40.47%            NaN                    8.70
# 7        47.65%            NaN                   10.77
# 8         1.93%            NaN                   10.69
# 9        46.36%            NaN                   33.94
# 10       20.65%            NaN                   11.19
# 11      110.52%            NaN                   16.77
# 12      109.96%            NaN                   23.83
# 13       -2.73%            NaN                   24.77
# 14       87.71%            NaN                    8.08
# 15       40.96%            NaN                   13.49
# ...

# %%
df.to_csv("nikkei_pe.csv")
