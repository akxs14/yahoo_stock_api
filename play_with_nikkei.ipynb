# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("nikkei_pe.csv")

# %%
df[df.pe != 0].sort_values("pe").head(50)
# Out:
#      Unnamed: 0      cap        es                                     name  \
# 300         300    0.000     0.000                         Papanets Co Ltd
# 643         643    0.000     9.645    Nagano Tokyu Department Store Co Ltd
# 198         198    2.644   119.900                          Three F Co Ltd
# 384         384  745.656   156.000    Tokyo Electric Power Co Holdings Inc
# 467         467    1.202   436.300    Kyowa Engineering Consultants Co Ltd
# 233         233    6.842  1013.900                            Asagami Corp
# 527         527   10.895   240.000      UNIMAT Retirement Community Co Ltd
# 120         120   19.385   283.600                           CRE Inc/Japan
# 183         183    4.107    82.000                               Nippo Ltd
# 164         164    8.566    58.600                     Urbanet Corp Co Ltd
# 74           74   18.283    67.700                        Accretive Co Ltd
# ...
